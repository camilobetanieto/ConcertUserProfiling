# %% [markdown]
# # Association of the *compressed* trajectories with the events

# %% [markdown]
# In the end, I need each point of the users' trajectories to be associated with their corresponding event. This notebook performs the operations needed for that. It takes as input the (fixed) timetables, the (fixed) GIS polygons, and the (reduced) connections.
#
# This file first filters the connection data and then associates it with their corresponding events.

# %%
import os

import pandas as pd
import geopandas as gpd
import h3

from shapely.geometry import Point

# %%
# Importing a custom module in a different file
import sys
sys.path.append('C:\Camilo\Estudio\Padova\Master thesis\master-thesis-code')
import constants

# %% [markdown]
# Assigning the path to read the preprocessed trajectories files:

# %%
path_trajectories_preprocessed = r'..\..\Datasets\Processed\trajectories_preprocessed'

# %% [markdown]
# Assigning the path to write the trajectories files with their associated events (the result of this script):

# %%
path_trajectories_events = r'..\..\Datasets\Processed\trajectories_events'

# %% [markdown]
# For both Sónar by night and Sónar by day, I first need to read the timetables.

# %%
# Reading the timetables and renaming two columns for clarity
sonar_timetables = pd.read_csv(r'..\..\Datasets\Processed\sonar_timetables_preprocessed.csv',
                               parse_dates = ['start_datetime','end_datetime'])
sonar_timetables.rename(columns={'title':'event_title','activity':'activity_type'}, inplace=True)

# Adding the timezone information so that the times are handled correctly
sonar_timetables['start_datetime'] = sonar_timetables['start_datetime'].dt.tz_localize('Europe/Madrid')
sonar_timetables['end_datetime'] = sonar_timetables['end_datetime'].dt.tz_localize('Europe/Madrid')

# %%
# Selecting only the relevant columns
sonar_timetables = sonar_timetables[['sonar_type', 'day_label', 'start_datetime', 'end_datetime',
                                     'event_title', 'activity_type', 'stage', 'music_type',
                                     'genre','genre_grouped','views_youtube']]

# %%
sonar_timetables.dtypes
# Out:
# sonar_type                               object
# day_label                                object
# start_datetime    datetime64[ns, Europe/Madrid]
# end_datetime      datetime64[ns, Europe/Madrid]
# event_title                              object
# activity_type                            object
# stage                                    object
# music_type                               object
# genre                                    object
# genre_grouped                            object
# views_youtube                           float64
# dtype: object

# %% [markdown]
# ## Association - Sónar by night process

# %% [markdown]
# ### Associating the timetables with the polygons

# %% [markdown]
# As a starting point, I need an intermediate table that associates the timetables with their geographical information (contained in the polygons).

# %%
# Reading the polygons and combining them in a single GeoDataFrame
night_polygons_clipped = gpd.read_file(r'..\..\Datasets\Processed\Zonas SONAR clipped\sonar_night_polygons_clipped.json')

# %%
sonar_timetables
# Out:
#          sonar_type         day_label            start_datetime  \
# 0      Sónar by Day  Thursday 13 June 2024-06-13 15:00:00+02:00
# 1      Sónar by Day  Thursday 13 June 2024-06-13 16:05:00+02:00
# 2      Sónar by Day  Thursday 13 June 2024-06-13 17:00:00+02:00
# 3      Sónar by Day  Thursday 13 June 2024-06-13 18:20:00+02:00
# 4      Sónar by Day  Thursday 13 June 2024-06-13 19:05:00+02:00
# ..              ...               ...                       ...
# 141  Sónar by Night    Friday 15 June 2024-06-16 01:05:00+02:00
# 142  Sónar by Night    Friday 15 June 2024-06-16 02:05:00+02:00
# 143  Sónar by Night    Friday 15 June 2024-06-16 03:05:00+02:00
# 144  Sónar by Night    Friday 15 June 2024-06-16 04:00:00+02:00
# 145  Sónar by Night    Friday 15 June 2024-06-16 05:00:00+02:00
#
#                  end_datetime  \
# 0   2024-06-13 16:00:00+02:00
# 1   2024-06-13 16:50:00+02:00
# 2   2024-06-13 18:10:00+02:00
# 3   2024-06-13 19:00:00+02:00
# 4   2024-06-13 20:30:00+02:00
# ..                        ...
# 141 2024-06-16 01:55:00+02:00
# 142 2024-06-16 02:55:00+02:00
# 143 2024-06-16 03:55:00+02:00
# 144 2024-06-16 04:50:00+02:00
# 145 2024-06-16 06:00:00+02:00
#
#                                            event_title activity_type  \
# 0                                              Rumbler         Music
# 1                                                 Huda         Music
# 2       Olof Dreijer & Diva Cruz (DJ + Percussion set)         Music
# 3                                          Toya Delazy         Music
# 4                                           Surusinghe         Music
# ..                                                 ...           ...
# 141                                        Club Cringe         Music
# 142                                   Julietta Ferrari         Music
# 143                                           Soto Asa         Music
# 144                                            Drazzit         Music
# 145  BLEX: Filip Custic, Virgen Maria, Naive Suprem...         Music
#
#             stage music_type          genre        genre_grouped  \
# 0    SonarVillage         DJ            NaN                  NaN
# 1    SonarVillage       LIVE            NaN                  NaN
# 2    SonarVillage       LIVE            NaN                  NaN
# 3    SonarVillage       LIVE            NaN                  NaN
# 4    SonarVillage         DJ            NaN                  NaN
# ..            ...        ...            ...                  ...
# 141      SonarCar         DJ   Experimental  electronic_hypnotic
# 142      SonarCar         DJ   Experimental  electronic_hypnotic
# 143      SonarCar       LIVE      Reggaeton         other_genres
# 144      SonarCar         DJ  Trance/Techno  electronic_hypnotic
# 145      SonarCar         DJ   Experimental  electronic_hypnotic
#
#      views_youtube
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 141        55831.0
# 142            0.0
# 143    153053094.0
# 144        22948.0
# 145       108825.0
#
# [146 rows x 11 columns]

# %%
# In this case I use an outer join because there are events 
# with no geographic information associated to them (e.g. they happen at Room+D -I did not find the corresponding polygon-),
# or are places that are not related to events (e.g. cashless areas, restaurants, etc.)
# and I do not want to discard any of them yet
night_timetables_polygons = pd.merge(sonar_timetables.loc[sonar_timetables['sonar_type']=='Sónar by Night'], 
                                     night_polygons_clipped[['polygon_name','source_gis_file','stage','stage_area_m2','geometry']],
                                     how='outer', on='stage')
night_timetables_polygons.sort_values(by=['sonar_type','day_label','event_title'], inplace=True)
night_timetables_polygons = gpd.GeoDataFrame(night_timetables_polygons)
night_timetables_polygons.drop(columns='geometry').head()
# Out:
#         sonar_type       day_label            start_datetime  \
# 51  Sónar by Night  Friday 14 June 2024-06-15 02:30:00+02:00
# 52  Sónar by Night  Friday 14 June 2024-06-15 02:30:00+02:00
# 53  Sónar by Night  Friday 14 June 2024-06-15 02:30:00+02:00
# 54  Sónar by Night  Friday 14 June 2024-06-15 02:30:00+02:00
# 55  Sónar by Night  Friday 14 June 2024-06-15 02:30:00+02:00
#
#                 end_datetime event_title activity_type      stage music_type  \
# 51 2024-06-15 04:00:00+02:00  Adriatique         Music  SonarClub         DJ
# 52 2024-06-15 04:00:00+02:00  Adriatique         Music  SonarClub         DJ
# 53 2024-06-15 04:00:00+02:00  Adriatique         Music  SonarClub         DJ
# 54 2024-06-15 04:00:00+02:00  Adriatique         Music  SonarClub         DJ
# 55 2024-06-15 04:00:00+02:00  Adriatique         Music  SonarClub         DJ
#
#                  genre          genre_grouped  views_youtube  \
# 51  General electronic  electronic_accessible     28697840.0
# 52  General electronic  electronic_accessible     28697840.0
# 53  General electronic  electronic_accessible     28697840.0
# 54  General electronic  electronic_accessible     28697840.0
# 55  General electronic  electronic_accessible     28697840.0
#
#                             polygon_name source_gis_file  stage_area_m2
# 51            SONAR NIT  - Zona VIP Club           av1-2          14914
# 52      SONAR NIT  - Zona VIP Club Barra           av1-2          14914
# 53                 SONAR NIT - SonarClub              p2          14914
# 54  SONAR NIT - SonarClub Barra la Nueva              p2          14914
# 55           SONAR NIT - SonarClub Barra              p2          14914

# %% [markdown]
# I need to add a start_datetime and a end_datetime for the polygons that are not in the timetables, so that I do not lose the observations that fall in these zones when filtering by time.

# %%
night_timetables_polygons.loc[night_timetables_polygons['event_title'].isna()].drop(columns='geometry')
# Out:
#   sonar_type day_label start_datetime end_datetime event_title activity_type  \
# 0        NaN       NaN            NaT          NaT         NaN           NaN
# 1        NaN       NaN            NaT          NaT         NaN           NaN
# 2        NaN       NaN            NaT          NaT         NaN           NaN
# 3        NaN       NaN            NaT          NaT         NaN           NaN
# 4        NaN       NaN            NaT          NaT         NaN           NaN
#
#                     stage music_type genre genre_grouped  views_youtube  \
# 0            NA-Cashless1        NaN   NaN           NaN            NaN
# 1              NA-Entrada        NaN   NaN           NaN            NaN
# 2         NA-Restauración        NaN   NaN           NaN            NaN
# 3        NA-autos_choques        NaN   NaN           NaN            NaN
# 4  NA-autos_choques_barra        NaN   NaN           NaN            NaN
#
#                          polygon_name source_gis_file  stage_area_m2
# 0              SONAR NIT - Cashless 1              p2            947
# 1                 SONAR NIT - Entrada              p1           5438
# 2            SONAR NIT - Restauración              p3           5695
# 3        SONAR NIT - Autos de choques              p3           1522
# 4  SONAR NIT - Autos de choques Barra              p3           1609

# %%
# Adding the start time and the end_datetime as the minimum and maximum times considered for the festival
# These were defined in the 3.preprocessing_filtering_splitting file and stored in the constants.py file

start_night_1 = pd.Timestamp(constants.START_NIGHT_1_STRING, tz='Europe/Madrid')
end_night_2 = pd.Timestamp(constants.END_NIGHT_2_STRING, tz='Europe/Madrid')

night_timetables_polygons.loc[night_timetables_polygons['event_title'].isna(),'start_datetime'] = start_night_1
night_timetables_polygons.loc[night_timetables_polygons['event_title'].isna(),'end_datetime'] = end_night_2

# I also add some explicit labels for clarity
night_timetables_polygons.loc[night_timetables_polygons['event_title'].isna(),'sonar_type'] = 'Sónar by Night'
night_timetables_polygons.loc[night_timetables_polygons['event_title'].isna(),'event_title'] = 'No event'

# Print to visualize the changes
night_timetables_polygons.loc[night_timetables_polygons['event_title']=='No event'].drop(columns='geometry')
# Out:
#        sonar_type day_label            start_datetime  \
# 0  Sónar by Night       NaN 2024-06-14 19:50:00+02:00
# 1  Sónar by Night       NaN 2024-06-14 19:50:00+02:00
# 2  Sónar by Night       NaN 2024-06-14 19:50:00+02:00
# 3  Sónar by Night       NaN 2024-06-14 19:50:00+02:00
# 4  Sónar by Night       NaN 2024-06-14 19:50:00+02:00
#
#                end_datetime event_title activity_type                   stage  \
# 0 2024-06-16 08:00:00+02:00    No event           NaN            NA-Cashless1
# 1 2024-06-16 08:00:00+02:00    No event           NaN              NA-Entrada
# 2 2024-06-16 08:00:00+02:00    No event           NaN         NA-Restauración
# 3 2024-06-16 08:00:00+02:00    No event           NaN        NA-autos_choques
# 4 2024-06-16 08:00:00+02:00    No event           NaN  NA-autos_choques_barra
#
#   music_type genre genre_grouped  views_youtube  \
# 0        NaN   NaN           NaN            NaN
# 1        NaN   NaN           NaN            NaN
# 2        NaN   NaN           NaN            NaN
# 3        NaN   NaN           NaN            NaN
# 4        NaN   NaN           NaN            NaN
#
#                          polygon_name source_gis_file  stage_area_m2
# 0              SONAR NIT - Cashless 1              p2            947
# 1                 SONAR NIT - Entrada              p1           5438
# 2            SONAR NIT - Restauración              p3           5695
# 3        SONAR NIT - Autos de choques              p3           1522
# 4  SONAR NIT - Autos de choques Barra              p3           1609

# %% [markdown]
# ### Associating each trajectory point to their corresponding stage

# %% [markdown]
# I can read the trajectories dataframe without scikit-mobility (I do not need any of the functionalities).

# %%
trajectories_night = pd.read_csv(os.path.join(path_trajectories_preprocessed, 'tdf_night_preprocessed_compressed.csv'), dtype={'vendor_name':str})

# %% [markdown]
# Converting to a GeoDataframe with the adequate characteristics.

# %%
# Getting the geometry and converting to Geotadaframe
trajectories_night['geometry'] = gpd.points_from_xy(trajectories_night['lng'], trajectories_night['lat'])
trajectories_night = gpd.GeoDataFrame(trajectories_night, geometry='geometry', crs=night_timetables_polygons.crs)

# Converting the date
trajectories_night['datetime'] = pd.to_datetime(trajectories_night['datetime'])
trajectories_night['datetime'] = trajectories_night['datetime'].dt.tz_convert('Europe/Madrid')

# %%
trajectories_night.dtypes
# Out:
# uid                                                         object
# macaddr_randomized                                           int64
# tid                                                          int64
# datetime                             datetime64[ns, Europe/Madrid]
# timestamp_ap                                                 int64
# lat                                                        float64
# lng                                                        float64
# vendor_name                                                 object
# h3_cell_original                                            object
# stage_original                                              object
# observations_user_night_original                             int64
# timespan_minutes_night_original                            float64
# num_distinct_stage_night_original                            int64
# minutes_per_stage_original                                 float64
# geometry                                                  geometry
# dtype: object

# %% [markdown]
# Performing a spatial join with just the polygons to check the join is correctly performed (before perfroming the actual join with the night_timetables_polygons). I check both the inner join and the left join to see if there are differences.

# %%
night_trajs_sjoin_left = gpd.sjoin(trajectories_night, night_polygons_clipped[['polygon_name','source_gis_file','stage','stage_area_m2','geometry']], how='left', predicate='within')

print('Shape after left join:')
night_trajs_sjoin_left.shape
# Out:
# Shape after left join:
# (630782, 20)

# %%
night_trajs_sjoin_inner = gpd.sjoin(trajectories_night, night_polygons_clipped[['polygon_name','source_gis_file','stage','stage_area_m2','geometry']], how='inner', predicate='within')

print('Shape after inner join:')
night_trajs_sjoin_inner.shape
# Out:
# Shape after inner join:
# (630781, 20)

# %%
# There are few not joined points, which might correspond to a small change of position due to the trajectory compression
no_points_in_polygon = night_trajs_sjoin_left[night_trajs_sjoin_left['polygon_name'].isna()]
no_points_in_polygon.drop(columns='geometry')
# Out:
#                                                      uid  macaddr_randomized  \
# 62120  1b18a57e83edac30d0fb7fb8edccefb6e04a8bf0544e46...                   1
#
#        tid                  datetime  timestamp_ap        lat       lng  \
# 62120    1 2024-06-15 02:56:55+02:00    1718413015  41.354855  2.132505
#
#       vendor_name h3_cell_original stage_original  \
# 62120         NaN  8d394461e86c43f       SonarPub
#
#        observations_user_night_original  timespan_minutes_night_original  \
# 62120                              1108                           339.93
#
#        num_distinct_stage_night_original  minutes_per_stage_original  \
# 62120                                  7                       48.56
#
#        index_right polygon_name source_gis_file stage  stage_area_m2
# 62120          NaN          NaN             NaN   NaN            NaN

# %% [markdown]
# ### Associating each trajectory point to an event

# %% [markdown]
# As practically all the points were joined, for a cleaner output, I apply the inner join with the night_polygons_clipped and obtain the stages and their corresponding event timetables.

# %%
trajectories_events_night = gpd.sjoin(trajectories_night, night_timetables_polygons, how='inner', predicate='within')
trajectories_events_night.shape
# Out:
# (6898356, 30)

# %% [markdown]
# To make the association with the actual events, I need to filter with the hour of the events.

# %%
# Keep only rows where the datetime is within the event's start and end time
# There is no overlap between the events that happen in the same stage, so I can use the <= condition on the upper bound
trajectories_events_matched_night = trajectories_events_night.loc[(trajectories_events_night['datetime'] >= trajectories_events_night['start_datetime']) &
                                                                 (trajectories_events_night['datetime'] <= trajectories_events_night['end_datetime'])]
trajectories_events_matched_night.shape
# Out:
# (573394, 30)

# %% [markdown]
# There are points that were geographically found, but were discarded with the time of events. In order to keep those trajectory points, I can find the difference between the dataframes.
#
# Since there are not duplicates of uid and datetime anymore, I can find the unmatched trajectory points and add them back to the matched trajectory points (with a specific label) and obtain the filtered trajectories_events_night.

# %%
# There are no duplicated trajectory points based on 'anonymized_macaddr' and 'datetime'
duplicates_traj_night = night_trajs_sjoin_inner.groupby(['uid', 'datetime']).size().reset_index(name='duplicate_count')
print(f'Duplicate count based on uid and datetime: {len(duplicates_traj_night[duplicates_traj_night["duplicate_count"] > 1])}')
# Out:
# Duplicate count based on uid and datetime: 0

# %%
def get_unmatched_points(reference_df, other_df, columns_join):
    
    merged = pd.merge(reference_df, other_df, 
                      on=columns_join,
                      indicator=True, how='left')
    diff_df = merged[merged['_merge'] == 'left_only']
    del diff_df['_merge']
    return diff_df

# %%
unmatched_points_events_night = get_unmatched_points(reference_df=night_trajs_sjoin_inner,
                                                     other_df=trajectories_events_matched_night[['uid','datetime', 'event_title']],
                                                     columns_join=['uid','datetime'])
unmatched_points_events_night.drop(columns='geometry')
# Out:
#                                                       uid  macaddr_randomized  \
# 29      00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 30      00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 31      00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 32      00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 228     00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# ...                                                   ...                 ...
# 630578  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630629  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630630  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630631  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630632  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
#
#         tid                  datetime  timestamp_ap        lat       lng  \
# 29        2 2024-06-15 23:33:11+02:00    1718487191  41.354105  2.129860
# 30        2 2024-06-15 23:33:25+02:00    1718487205  41.354046  2.129898
# 31        2 2024-06-15 23:33:36+02:00    1718487216  41.353951  2.129868
# 32        2 2024-06-15 23:33:42+02:00    1718487222  41.353923  2.129927
# 228       2 2024-06-16 03:57:09+02:00    1718503029  41.356073  2.130682
# ...     ...                       ...           ...        ...       ...
# 630578    1 2024-06-15 01:48:07+02:00    1718408887  41.354516  2.130759
# 630629    1 2024-06-15 03:21:29+02:00    1718414489  41.354137  2.130741
# 630630    1 2024-06-15 03:23:09+02:00    1718414589  41.354479  2.130749
# 630631    1 2024-06-15 03:23:57+02:00    1718414637  41.354137  2.130741
# 630632    1 2024-06-15 03:24:59+02:00    1718414699  41.354479  2.130749
#
#        vendor_name h3_cell_original         stage_original  \
# 29             NaN  8d394461e82927f              SonarClub
# 30             NaN  8d394461e8292ff              SonarClub
# 31             NaN  8d394461e87693f              SonarClub
# 32             NaN  8d394461e87683f              SonarClub
# 228            NaN  8d394461e94c7bf               SonarCar
# ...            ...              ...                    ...
# 630578         NaN  8d394461e8664bf  SonarLab x Printworks
# 630629         NaN  8d394461e8757bf  SonarLab x Printworks
# 630630         NaN  8d394461e87587f  SonarLab x Printworks
# 630631         NaN  8d394461e8757bf  SonarLab x Printworks
# 630632         NaN  8d394461e87587f  SonarLab x Printworks
#
#         observations_user_night_original  timespan_minutes_night_original  \
# 29                                   586                           340.90
# 30                                   586                           340.90
# 31                                   586                           340.90
# 32                                   586                           340.90
# 228                                  586                           340.90
# ...                                  ...                              ...
# 630578                               714                           510.43
# 630629                               714                           510.43
# 630630                               714                           510.43
# 630631                               714                           510.43
# 630632                               714                           510.43
#
#         num_distinct_stage_night_original  minutes_per_stage_original  \
# 29                                      7                       48.70
# 30                                      7                       48.70
# 31                                      7                       48.70
# 32                                      7                       48.70
# 228                                     7                       48.70
# ...                                   ...                         ...
# 630578                                  5                      102.09
# 630629                                  5                      102.09
# 630630                                  5                      102.09
# 630631                                  5                      102.09
# 630632                                  5                      102.09
#
#         index_right           polygon_name source_gis_file  \
# 29                9  SONAR NIT - SonarClub              p2
# 30                9  SONAR NIT - SonarClub              p2
# 31                9  SONAR NIT - SonarClub              p2
# 32                9  SONAR NIT - SonarClub              p2
# 228              14   SONAR NIT - SonarCar              p3
# ...             ...                    ...             ...
# 630578            2   SONAR NIT - SonarLab           av2-3
# 630629            2   SONAR NIT - SonarLab           av2-3
# 630630            2   SONAR NIT - SonarLab           av2-3
# 630631            2   SONAR NIT - SonarLab           av2-3
# 630632            2   SONAR NIT - SonarLab           av2-3
#
#                         stage  stage_area_m2 event_title
# 29                  SonarClub          14914         NaN
# 30                  SonarClub          14914         NaN
# 31                  SonarClub          14914         NaN
# 32                  SonarClub          14914         NaN
# 228                  SonarCar           2688         NaN
# ...                       ...            ...         ...
# 630578  SonarLab x Printworks           9171         NaN
# 630629  SonarLab x Printworks           9171         NaN
# 630630  SonarLab x Printworks           9171         NaN
# 630631  SonarLab x Printworks           9171         NaN
# 630632  SonarLab x Printworks           9171         NaN
#
# [57387 rows x 20 columns]

# %% [markdown]
# Assigning an explicit label for the event title and concatenating the two dataframes into the final `trajectories_events_night`.

# %%
unmatched_points_events_night['event_title'] = 'No event'

# %% [markdown]
# **The points were correctly associated with their corresponding events.** The difference in size between this table and the original trajectories is just the points that do not fall within the polygons anymore due to the trajectory compression.

# %%
trajectories_events_night = pd.concat([trajectories_events_matched_night, unmatched_points_events_night]).sort_values(by=['uid','datetime'])
trajectories_events_night.drop(columns='geometry')
# Out:
#                                                       uid  macaddr_randomized  \
# 0       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 1       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 2       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 3       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 4       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# ...                                                   ...                 ...
# 630777  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630778  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630779  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630780  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630781  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
#
#         tid                  datetime  timestamp_ap        lat       lng  \
# 0         2 2024-06-15 22:38:47+02:00    1718483927  41.353501  2.129162
# 1         2 2024-06-15 22:39:19+02:00    1718483959  41.353440  2.129005
# 2         2 2024-06-15 22:40:37+02:00    1718484037  41.353501  2.129162
# 3         2 2024-06-15 22:49:15+02:00    1718484555  41.353426  2.128963
# 4         2 2024-06-15 22:49:21+02:00    1718484561  41.353365  2.128970
# ...     ...                       ...           ...        ...       ...
# 630777    1 2024-06-15 06:26:21+02:00    1718425581  41.354558  2.130617
# 630778    1 2024-06-15 06:26:35+02:00    1718425595  41.354326  2.130864
# 630779    1 2024-06-15 06:27:57+02:00    1718425677  41.354300  2.130898
# 630780    1 2024-06-15 06:28:41+02:00    1718425721  41.354254  2.130618
# 630781    1 2024-06-15 06:31:37+02:00    1718425897  41.353698  2.132315
#
#        vendor_name h3_cell_original         stage_original  ...  \
# 0              NaN  8d394461e82b5bf             NA-Entrada  ...
# 1              NaN  8d394461e82a67f             NA-Entrada  ...
# 2              NaN  8d394461e82b5bf             NA-Entrada  ...
# 3              NaN  8d394461e82a67f             NA-Entrada  ...
# 4              NaN  8d394461e82a6ff             NA-Entrada  ...
# ...            ...              ...                    ...  ...
# 630777         NaN  8d394461e95b2ff  SonarLab x Printworks  ...
# 630778         NaN  8d394461e875abf  SonarLab x Printworks  ...
# 630779         NaN  8d394461e87533f  SonarLab x Printworks  ...
# 630780         NaN  8d394461e875cff  SonarLab x Printworks  ...
# 630781         NaN  8d394461e84027f        NA-Restauración  ...
#
#                      event_title  activity_type                  stage  \
# 0                       No event            NaN             NA-Entrada
# 1                       No event            NaN             NA-Entrada
# 2                       No event            NaN             NA-Entrada
# 3                       No event            NaN             NA-Entrada
# 4                       No event            NaN             NA-Entrada
# ...                          ...            ...                    ...
# 630777  DJ Flight & MC Chickaboo          Music  SonarLab x Printworks
# 630778  DJ Flight & MC Chickaboo          Music  SonarLab x Printworks
# 630779  DJ Flight & MC Chickaboo          Music  SonarLab x Printworks
# 630780  DJ Flight & MC Chickaboo          Music  SonarLab x Printworks
# 630781                  No event            NaN        NA-Restauración
#
#         music_type          genre        genre_grouped views_youtube  \
# 0              NaN            NaN                  NaN           NaN
# 1              NaN            NaN                  NaN           NaN
# 2              NaN            NaN                  NaN           NaN
# 3              NaN            NaN                  NaN           NaN
# 4              NaN            NaN                  NaN           NaN
# ...            ...            ...                  ...           ...
# 630777          DJ  Drum and bass  electronic_hypnotic           0.0
# 630778          DJ  Drum and bass  electronic_hypnotic           0.0
# 630779          DJ  Drum and bass  electronic_hypnotic           0.0
# 630780          DJ  Drum and bass  electronic_hypnotic           0.0
# 630781         NaN            NaN                  NaN           NaN
#
#                         polygon_name source_gis_file stage_area_m2
# 0                SONAR NIT - Entrada              p1          5438
# 1                SONAR NIT - Entrada              p1          5438
# 2                SONAR NIT - Entrada              p1          5438
# 3                SONAR NIT - Entrada              p1          5438
# 4                SONAR NIT - Entrada              p1          5438
# ...                              ...             ...           ...
# 630777          SONAR NIT - SonarLab           av2-3          9171
# 630778          SONAR NIT - SonarLab           av2-3          9171
# 630779  SONAR NIT - SonarLab Barra 1           av2-3          9171
# 630780          SONAR NIT - SonarLab           av2-3          9171
# 630781      SONAR NIT - Restauración              p3          5695
#
# [630781 rows x 29 columns]

# %% [markdown]
# ### Associating each updated trajectory point to their corresponding H3 cells

# %% [markdown]
# For plotting purposes, I also get the updated h3 cell from the h3 API. As the trajectory compression might have sligthly changed some locations, I recompute the h3_cell for safety.

# %%
trajectories_events_night['h3_cell'] = [h3.latlng_to_cell(lat, lng, 13) for lat, lng in zip(trajectories_events_night['lat'], trajectories_events_night['lng'])]

# %%
print(f"There are {(trajectories_events_night['h3_cell_original'] != trajectories_events_night['h3_cell']).sum()} points that changed their h3_cell after the trajectory preprocessing.")
# Out:
# There are 5981 points that changed their h3_cell after the trajectory preprocessing.

# %% [markdown]
# ## Association - Sónar by day process

# %% [markdown]
# #### Adjusting the timetables

# %% [markdown]
# I found that there were some events that have a time overlap in Sónar by Day that happen in the same space, and there is not a small-enough granularity to distinguish between the areas where these events happened. For this reason, I leave only the more general and correct 'Project area' label to these cases.

# %%
sonar_timetables = sonar_timetables.loc[(sonar_timetables['stage'] != 'Project Area') |
                                        ((sonar_timetables['stage'] == 'Project Area') & (sonar_timetables['event_title'] == 'Project Area'))]

# %% [markdown]
# As a starting point, I need an intermediate table that associates the timetables with their geographical information (contained in the polygons).

# %%
# Reading the polygons and combining them in a single GeoDataFrame
day_polygons_clipped = gpd.read_file(r'..\..\Datasets\Processed\Zonas SONAR clipped\sonar_day_polygons_clipped.json')

# %% [markdown]
# #### Adding the floor number to the stages in day_polygons_clipped

# %%
# Mapping the 'source_gis_file' column to the corresponding floor values (the default is floor 0)

floor_assignment = {'p5.2': 2, 'p5.1': 1}

day_polygons_clipped['polygon_floor'] = day_polygons_clipped['source_gis_file'].map(floor_assignment).fillna(0).astype('Int8')
day_polygons_clipped.drop(columns='geometry')
# Out:
#                                       id                      polygon_name  \
# 0   88259806-b543-45e9-b0e9-87b0ac826ce6             SONAR DIA - SonarPark
# 1   036a9d19-b2a9-45a9-aa74-0569fc82ba8c       SONAR DIA - SonarPark Barra
# 2   aa598ed7-0b28-444d-8564-b434e0e34b82        SONAR DIA - SonarHall Paso
# 3   cfcf08c7-1230-4df9-9309-6ef436090d99             SONAR DIA - SonarHall
# 4   97acc96a-1160-456d-abe7-4046ec78fc41           SONAR DIA - Food Trucks
# 5   a03c6c6f-b506-4915-bf7f-fc609b2e20e9               SONAR DIA - Stage+D
# 6   f10d8100-ef6d-468b-acc4-09f8497cac7c          SONAR DIA - SonarVillage
# 7   0e9222e8-38be-49bf-bbdd-46a37ce4a899      SONAR DIA - SonarVillage VIP
# 8   dc79c74e-b7e6-4a8d-9b6d-f8d20138e8c9  SONAR DIA - SonarVillage Barra 2
# 9   fd73b9fb-8b96-473e-80ff-b648b8a18005  SONAR DIA - SonarVillage Barra 1
# 10  ca9bc1ff-4dc9-47fe-9bd6-370d345133ae              SONAR DIA - Cashless
# 11  749e951a-1adb-43b8-b061-a3e382f30a70              SONAR DIA - Lounge+D
# 12  ccca956a-63a3-4585-b4ce-c85ffbb4af2f            SONAR DIA - SonarÀgora
# 13  7f331337-706f-4c60-ad92-366babb058ae          SONAR DIA - Lounge Barra
# 14  92e4ce9c-ae60-4960-a7a2-4d27def850bc          SONAR DIA - Project Area
# 15  115fff94-219b-47ed-9f46-0649a37ab93c    SONAR DIA - Project Area Barra
# 16  91dccca1-6ac3-462e-a1c7-3aaccd46cc7f          SONAR DIA - SonarComplex
#
#     index source_gis_file               stage  stage_area_m2  polygon_floor
# 0       0              p1           SonarPark           1914              0
# 1       1              p1           SonarPark           1914              0
# 2       0              p2  NA-sonar_hall_paso           6973              0
# 3       1              p2           SonarHall           1319              0
# 4       2              p2      NA-food_trucks           1714              0
# 5       3              p2             Stage+D            443              0
# 6       0              p3        SonarVillage           9366              0
# 7       1              p3        SonarVillage           9366              0
# 8       2              p3        SonarVillage           9366              0
# 9       3              p3        SonarVillage           9366              0
# 10      0              p4         NA-cashless            854              0
# 11      0            p5.0         NA-lounge+d            608              0
# 12      1            p5.0          SonarÀgora            583              0
# 13      2            p5.0     NA-lounge_barra            101              0
# 14      0            p5.1        Project Area           2603              1
# 15      1            p5.1        Project Area           2603              1
# 16      0            p5.2           Complex+D           1092              2

# %% [markdown]
# ### Associating the timetables with the polygons

# %%
# In this case I use an outer join because there are events 
# with no geographic information associated to them (e.g. they happen at Room+D -I did not find the corresponding polygon-),
# or are places that are not related to events (e.g. cashless areas, restaurants, etc.)
# and I do not want to discard any of them yet
day_timetables_polygons = pd.merge(sonar_timetables.loc[sonar_timetables['sonar_type']=='Sónar by Day'], 
                                     day_polygons_clipped[['polygon_name','source_gis_file','stage','stage_area_m2','polygon_floor','geometry']],
                                     how='outer', on='stage')
day_timetables_polygons.sort_values(by=['sonar_type','day_label','event_title'], inplace=True)
day_timetables_polygons = gpd.GeoDataFrame(day_timetables_polygons)
day_timetables_polygons.drop(columns='geometry').head(5)
# Out:
#       sonar_type       day_label            start_datetime  \
# 25  Sónar by Day  Friday 14 June 2024-06-14 10:00:00+02:00
# 54  Sónar by Day  Friday 14 June 2024-06-14 16:55:00+02:00
# 55  Sónar by Day  Friday 14 June 2024-06-14 16:55:00+02:00
# 3   Sónar by Day  Friday 14 June 2024-06-14 16:15:00+02:00
# 52  Sónar by Day  Friday 14 June 2024-06-14 15:45:00+02:00
#
#                 end_datetime                   event_title activity_type  \
# 25 2024-06-14 14:00:00+02:00     AI & WEB3 Creative Summit          Talk
# 54 2024-06-14 17:40:00+02:00                         AMORE         Music
# 55 2024-06-14 17:40:00+02:00                         AMORE         Music
# 3  2024-06-14 17:00:00+02:00  Adelaida presents 'Muérdago'         Music
# 52 2024-06-14 16:45:00+02:00                        Akazie         Music
#
#         stage music_type genre genre_grouped  views_youtube  \
# 25     Room+D        NaN   NaN           NaN            NaN
# 54  SonarPark       LIVE   NaN           NaN            NaN
# 55  SonarPark       LIVE   NaN           NaN            NaN
# 3   Complex+D       LIVE   NaN           NaN            NaN
# 52  SonarPark         DJ   NaN           NaN            NaN
#
#                    polygon_name source_gis_file  stage_area_m2  polygon_floor
# 25                          NaN             NaN            NaN           <NA>
# 54        SONAR DIA - SonarPark              p1         1914.0              0
# 55  SONAR DIA - SonarPark Barra              p1         1914.0              0
# 3      SONAR DIA - SonarComplex            p5.2         1092.0              2
# 52        SONAR DIA - SonarPark              p1         1914.0              0

# %% [markdown]
# I need to add a start_datetime and a end_datetime for the polygons that are not in the timetables, so that I do not lose the observations that fall in these zones when filtering by time.

# %%
day_timetables_polygons.loc[day_timetables_polygons['event_title'].isna()].drop(columns='geometry')
# Out:
#    sonar_type day_label start_datetime end_datetime event_title activity_type  \
# 12        NaN       NaN            NaT          NaT         NaN           NaN
# 13        NaN       NaN            NaT          NaT         NaN           NaN
# 14        NaN       NaN            NaT          NaT         NaN           NaN
# 15        NaN       NaN            NaT          NaT         NaN           NaN
# 16        NaN       NaN            NaT          NaT         NaN           NaN
#
#                  stage music_type genre genre_grouped  views_youtube  \
# 12         NA-cashless        NaN   NaN           NaN            NaN
# 13      NA-food_trucks        NaN   NaN           NaN            NaN
# 14         NA-lounge+d        NaN   NaN           NaN            NaN
# 15     NA-lounge_barra        NaN   NaN           NaN            NaN
# 16  NA-sonar_hall_paso        NaN   NaN           NaN            NaN
#
#                   polygon_name source_gis_file  stage_area_m2  polygon_floor
# 12        SONAR DIA - Cashless              p4          854.0              0
# 13     SONAR DIA - Food Trucks              p2         1714.0              0
# 14        SONAR DIA - Lounge+D            p5.0          608.0              0
# 15    SONAR DIA - Lounge Barra            p5.0          101.0              0
# 16  SONAR DIA - SonarHall Paso              p2         6973.0              0

# %%
# Adding the start time and the end_datetime as the minimum and maximum times considered for the festival
# These were defined in the 3.preprocessing_filtering_splitting file and stored in the constants.py file

start_day_1 = pd.Timestamp(constants.START_DAY_1_STRING, tz='Europe/Madrid')
end_day_3 = pd.Timestamp(constants.END_DAY_3_STRING, tz='Europe/Madrid')

day_timetables_polygons.loc[day_timetables_polygons['event_title'].isna(),'start_datetime'] = start_day_1
day_timetables_polygons.loc[day_timetables_polygons['event_title'].isna(),'end_datetime'] = end_day_3

# I also add some explicit labels for clarity
day_timetables_polygons.loc[day_timetables_polygons['event_title'].isna(),'sonar_type'] = 'Sónar by Day'
day_timetables_polygons.loc[day_timetables_polygons['event_title'].isna(),'event_title'] = 'No event'

# Print to visualize the changes
day_timetables_polygons.loc[day_timetables_polygons['event_title']=='No event'].drop(columns='geometry')
# Out:
#       sonar_type day_label            start_datetime  \
# 12  Sónar by Day       NaN 2024-06-13 09:30:00+02:00
# 13  Sónar by Day       NaN 2024-06-13 09:30:00+02:00
# 14  Sónar by Day       NaN 2024-06-13 09:30:00+02:00
# 15  Sónar by Day       NaN 2024-06-13 09:30:00+02:00
# 16  Sónar by Day       NaN 2024-06-13 09:30:00+02:00
#
#                 end_datetime event_title activity_type               stage  \
# 12 2024-06-16 00:00:00+02:00    No event           NaN         NA-cashless
# 13 2024-06-16 00:00:00+02:00    No event           NaN      NA-food_trucks
# 14 2024-06-16 00:00:00+02:00    No event           NaN         NA-lounge+d
# 15 2024-06-16 00:00:00+02:00    No event           NaN     NA-lounge_barra
# 16 2024-06-16 00:00:00+02:00    No event           NaN  NA-sonar_hall_paso
#
#    music_type genre genre_grouped  views_youtube                polygon_name  \
# 12        NaN   NaN           NaN            NaN        SONAR DIA - Cashless
# 13        NaN   NaN           NaN            NaN     SONAR DIA - Food Trucks
# 14        NaN   NaN           NaN            NaN        SONAR DIA - Lounge+D
# 15        NaN   NaN           NaN            NaN    SONAR DIA - Lounge Barra
# 16        NaN   NaN           NaN            NaN  SONAR DIA - SonarHall Paso
#
#    source_gis_file  stage_area_m2  polygon_floor
# 12              p4          854.0              0
# 13              p2         1714.0              0
# 14            p5.0          608.0              0
# 15            p5.0          101.0              0
# 16              p2         6973.0              0

# %% [markdown]
# In Sónar by Day, there are some events that will not be geographically matched because there is no exact reference of where they happened.

# %%
day_timetables_polygons.loc[day_timetables_polygons['polygon_name'].isna()].drop(columns='geometry')
# Out:
#       sonar_type         day_label            start_datetime  \
# 25  Sónar by Day    Friday 14 June 2024-06-14 10:00:00+02:00
# 26  Sónar by Day    Friday 14 June 2024-06-14 18:00:00+02:00
# 10  Sónar by Day    Friday 14 June 2024-06-14 15:00:00+02:00
# 27  Sónar by Day    Friday 14 June 2024-06-14 16:00:00+02:00
# 11  Sónar by Day  Saturday 15 June 2024-06-15 15:00:00+02:00
# 24  Sónar by Day  Thursday 13 June 2024-06-13 18:00:00+02:00
# 9   Sónar by Day  Thursday 13 June 2024-06-13 15:00:00+02:00
# 23  Sónar by Day  Thursday 13 June 2024-06-13 11:00:00+02:00
#
#                 end_datetime  \
# 25 2024-06-14 14:00:00+02:00
# 26 2024-06-14 19:00:00+02:00
# 10 2024-06-14 21:00:00+02:00
# 27 2024-06-14 18:00:00+02:00
# 11 2024-06-15 21:00:00+02:00
# 24 2024-06-13 19:00:00+02:00
# 9  2024-06-13 21:00:00+02:00
# 23 2024-06-13 13:30:00+02:00
#
#                                           event_title activity_type  \
# 25                          AI & WEB3 Creative Summit          Talk
# 26            AlphaTheta presents 'Euphonia' Workshop    Networking
# 10                                       Espai Oníric    Exhibition
# 27  Future of Music with Revelator Labs & MUSIC x:...          Talk
# 11                                       Espai Oníric    Exhibition
# 24                             All Our Minds Workshop      Workshop
# 9                                        Espai Oníric    Exhibition
# 23                                Music Tech Sessions    Networking
#
#            stage music_type genre genre_grouped  views_youtube polygon_name  \
# 25        Room+D        NaN   NaN           NaN            NaN          NaN
# 26        Room+D        NaN   NaN           NaN            NaN          NaN
# 10  Espai Oníric        NaN   NaN           NaN            NaN          NaN
# 27      Room+D 2        NaN   NaN           NaN            NaN          NaN
# 11  Espai Oníric        NaN   NaN           NaN            NaN          NaN
# 24        Room+D        NaN   NaN           NaN            NaN          NaN
# 9   Espai Oníric        NaN   NaN           NaN            NaN          NaN
# 23        Room+D        NaN   NaN           NaN            NaN          NaN
#
#    source_gis_file  stage_area_m2  polygon_floor
# 25             NaN            NaN           <NA>
# 26             NaN            NaN           <NA>
# 10             NaN            NaN           <NA>
# 27             NaN            NaN           <NA>
# 11             NaN            NaN           <NA>
# 24             NaN            NaN           <NA>
# 9              NaN            NaN           <NA>
# 23             NaN            NaN           <NA>

# %% [markdown]
# ### Associating each trajectory point to their corresponding stage

# %% [markdown]
# I can read the trajectories dataframe without scikit-mobility (I do not need any of the functionalities).

# %%
trajectories_day = pd.read_csv(os.path.join(path_trajectories_preprocessed, 'tdf_day_preprocessed_compressed.csv'), 
                               dtype={'floor_num_added':'Int8', 'vendor_name':str})
trajectories_day.shape
# Out:
# (1191053, 16)

# %% [markdown]
# Converting to a GeoDataframe with the adequate characteristics.

# %%
# Getting the geometry and converting to Geotadaframe
trajectories_day['geometry'] = gpd.points_from_xy(trajectories_day['lng'], trajectories_day['lat'])
trajectories_day = gpd.GeoDataFrame(trajectories_day, geometry='geometry', crs=night_timetables_polygons.crs)

# Converting the date
trajectories_day['datetime'] = pd.to_datetime(trajectories_day['datetime'])
trajectories_day['datetime'] = trajectories_day['datetime'].dt.tz_convert('Europe/Madrid')

# %%
trajectories_day.dtypes
# Out:
# uid                                                       object
# macaddr_randomized                                         int64
# tid                                                        int64
# floor_num_added                                             Int8
# label_day_floor_change_id                                 object
# datetime                           datetime64[ns, Europe/Madrid]
# timestamp_ap                                               int64
# lat                                                      float64
# lng                                                      float64
# vendor_name                                               object
# h3_cell_original                                          object
# stage_original                                            object
# observations_user_day_original                             int64
# timespan_minutes_day_original                            float64
# num_distinct_stage_day_original                            int64
# minutes_per_stage_original                               float64
# geometry                                                geometry
# dtype: object

# %% [markdown]
# Performing a spatial join with just the polygons to check the join is correctly performed (before perfroming the actual join with the night_timetables_polygons). I check both the inner join and the left join to see if there are differences. At this point, a point could be associated to multiple plygons because of the oerlap of polygons in the multi-floor area. This will be later filtered.

# %%
day_trajs_sjoin_left = gpd.sjoin(trajectories_day, day_polygons_clipped[['polygon_name','source_gis_file','polygon_floor','stage','stage_area_m2','geometry']], how='left', predicate='within')


print('Shape after left join:')
day_trajs_sjoin_left.shape
# Out:
# Shape after left join:
# (1255049, 23)

# %%
day_trajs_sjoin_inner = gpd.sjoin(trajectories_day, day_polygons_clipped[['polygon_name','source_gis_file','polygon_floor','stage','stage_area_m2','geometry']], how='inner', predicate='within')

print('Shape after inner join:')
day_trajs_sjoin_inner.shape
# Out:
# Shape after inner join:
# (1255045, 23)

# %%
# There are few not joined points, which might correspond to a small change of position due to the trajectory compression
no_points_in_polygon = day_trajs_sjoin_left[(day_trajs_sjoin_left['polygon_name'].isna())]
no_points_in_polygon.drop(columns='geometry')
# Out:
#                                                       uid  macaddr_randomized  \
# 412132  544216fa2250cf4925003407403cba9c1d0c46019a29ba...                   1
# 412137  544216fa2250cf4925003407403cba9c1d0c46019a29ba...                   1
# 925297  c1f1d408cdda39d3a7d46b0395afae9f8fd48649cae223...                   1
# 925300  c1f1d408cdda39d3a7d46b0395afae9f8fd48649cae223...                   1
#
#         tid  floor_num_added label_day_floor_change_id  \
# 412132    3                0                       3_4
# 412137    3                0                       3_4
# 925297    2                0                       2_0
# 925300    2                0                       2_0
#
#                         datetime  timestamp_ap        lat       lng  \
# 412132 2024-06-15 17:20:53+02:00    1718464853  41.372194  2.151736
# 412137 2024-06-15 17:22:43+02:00    1718464963  41.372194  2.151736
# 925297 2024-06-14 23:03:57+02:00    1718399037  41.373066  2.151757
# 925300 2024-06-14 23:05:46+02:00    1718399146  41.373066  2.151757
#
#        vendor_name  ... observations_user_day_original  \
# 412132         NaN  ...                           1190
# 412137         NaN  ...                           1190
# 925297         NaN  ...                           2480
# 925300         NaN  ...                           2480
#
#        timespan_minutes_day_original  num_distinct_stage_day_original  \
# 412132                        354.87                                7
# 412137                        354.87                                7
# 925297                        490.32                                4
# 925300                        490.32                                4
#
#         minutes_per_stage_original  index_right  polygon_name  \
# 412132                       50.70          NaN           NaN
# 412137                       50.70          NaN           NaN
# 925297                      122.58          NaN           NaN
# 925300                      122.58          NaN           NaN
#
#         source_gis_file polygon_floor stage  stage_area_m2
# 412132              NaN          <NA>   NaN            NaN
# 412137              NaN          <NA>   NaN            NaN
# 925297              NaN          <NA>   NaN            NaN
# 925300              NaN          <NA>   NaN            NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Associating each trajectory point to an event

# %% [markdown]
# As practically all the points were joined, for a cleaner output, I apply the inner join with the night_polygons_clipped and obtain the stages and their corresponding event timetables.

# %%
trajectories_events_day = gpd.sjoin(trajectories_day, day_timetables_polygons, how='inner', predicate='within')
trajectories_events_day.shape
# Out:
# (17881279, 33)

# %% [markdown]
# To make the association with the actual events, I need to filter with the hour of the events and the floor number.

# %%
# Keep only rows where the datetime is within the event's start and end time
# There is no overlap between the events that happen in the same stage, so I can use the <= condition on the upper bound
trajectories_events_matched_day = trajectories_events_day.loc[(trajectories_events_day['datetime'] >= trajectories_events_day['start_datetime']) &
                                                                 (trajectories_events_day['datetime'] <= trajectories_events_day['end_datetime']) &
                                                                 (trajectories_events_day['floor_num_added'] == trajectories_events_day['polygon_floor'])]
trajectories_events_matched_day.shape
# Out:
# (1029566, 33)

# %% [markdown]
# There are points that were geographically found, but were discarded with the time of events. In order to keep those trajectory points, I can find the difference in between the dataframes.
#
# Since there are not duplicates of uid and datetime anymore, I can find the unmatched trajectory points and add them back to the matched trajectory points (with a specific label) and obtain the filtered trajectories_events_night.

# %%
# There are no duplicated trajectory points based on 'anonymized_macaddr' and 'datetime'
duplicates_traj_day = day_trajs_sjoin_inner.loc[~day_trajs_sjoin_inner['source_gis_file'].isin(['p5.0','p5.1','p5.2'])].groupby(['uid', 'datetime']).size().reset_index(name='duplicate_count')
print(f'Duplicate count based on uid and datetime: {len(duplicates_traj_day[duplicates_traj_day["duplicate_count"] > 1])}')
# Out:
# Duplicate count based on uid and datetime: 0

# %% [markdown]
# In Sónar by day I need also to filter out the unmatched points that do not belong to the actual floor (this must be done after the association of the trajectories with the polgons)

# %%
# Getting the unmacthed points with the function defined above
unmatched_points_events_day = get_unmatched_points(reference_df=day_trajs_sjoin_inner,
                                                     other_df=trajectories_events_matched_day[['uid','datetime', 'event_title']],
                                                     columns_join=['uid','datetime'])

# Fltering out the points that do not correspond to 
unmatched_points_events_day = unmatched_points_events_day.loc[unmatched_points_events_day['floor_num_added'] == unmatched_points_events_day['polygon_floor']]

unmatched_points_events_day.drop(columns='geometry')
# Out:
#                                                        uid  \
# 5        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 6        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 7        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 8        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 9        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# ...                                                    ...
# 1255031  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255032  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255038  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255041  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255043  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
#
#          macaddr_randomized  tid  floor_num_added label_day_floor_change_id  \
# 5                         1    2                0                       2_0
# 6                         1    2                0                       2_0
# 7                         1    2                0                       2_0
# 8                         1    2                0                       2_0
# 9                         1    2                0                       2_0
# ...                     ...  ...              ...                       ...
# 1255031                   0    1                2                       1_1
# 1255032                   0    1                0                       1_2
# 1255038                   0    2                0                       2_0
# 1255041                   0    2                1                       2_1
# 1255043                   0    2                1                       2_3
#
#                          datetime  timestamp_ap        lat       lng  \
# 5       2024-06-14 18:00:22+02:00    1718380822  41.373378  2.152060
# 6       2024-06-14 18:02:21+02:00    1718380941  41.373387  2.151835
# 7       2024-06-14 18:02:34+02:00    1718380954  41.373582  2.151956
# 8       2024-06-14 18:04:08+02:00    1718381048  41.373375  2.152077
# 9       2024-06-14 18:04:23+02:00    1718381063  41.373582  2.151956
# ...                           ...           ...        ...       ...
# 1255031 2024-06-13 18:48:13+02:00    1718297293  41.372453  2.151916
# 1255032 2024-06-13 20:18:48+02:00    1718302728  41.372510  2.151637
# 1255038 2024-06-14 17:29:18+02:00    1718378958  41.372568  2.151624
# 1255041 2024-06-14 23:06:18+02:00    1718399178  41.372263  2.152061
# 1255043 2024-06-14 23:08:08+02:00    1718399288  41.372263  2.152061
#
#          vendor_name  ... timespan_minutes_day_original  \
# 5                NaN  ...                        256.27
# 6                NaN  ...                        256.27
# 7                NaN  ...                        256.27
# 8                NaN  ...                        256.27
# 9                NaN  ...                        256.27
# ...              ...  ...                           ...
# 1255031  Apple, Inc.  ...                        482.65
# 1255032  Apple, Inc.  ...                        482.65
# 1255038  Apple, Inc.  ...                        736.40
# 1255041  Apple, Inc.  ...                        736.40
# 1255043  Apple, Inc.  ...                        736.40
#
#         num_distinct_stage_day_original  minutes_per_stage_original  \
# 5                                     4                       64.07
# 6                                     4                       64.07
# 7                                     4                       64.07
# 8                                     4                       64.07
# 9                                     4                       64.07
# ...                                 ...                         ...
# 1255031                               4                      120.66
# 1255032                               4                      120.66
# 1255038                               4                      184.10
# 1255041                               4                      184.10
# 1255043                               4                      184.10
#
#          index_right              polygon_name  source_gis_file  \
# 5                  6  SONAR DIA - SonarVillage               p3
# 6                  6  SONAR DIA - SonarVillage               p3
# 7                  6  SONAR DIA - SonarVillage               p3
# 8                  6  SONAR DIA - SonarVillage               p3
# 9                  6  SONAR DIA - SonarVillage               p3
# ...              ...                       ...              ...
# 1255031           16  SONAR DIA - SonarComplex             p5.2
# 1255032           12    SONAR DIA - SonarÀgora             p5.0
# 1255038           12    SONAR DIA - SonarÀgora             p5.0
# 1255041           14  SONAR DIA - Project Area             p5.1
# 1255043           14  SONAR DIA - Project Area             p5.1
#
#          polygon_floor         stage stage_area_m2  event_title
# 5                    0  SonarVillage          9366          NaN
# 6                    0  SonarVillage          9366          NaN
# 7                    0  SonarVillage          9366          NaN
# 8                    0  SonarVillage          9366          NaN
# 9                    0  SonarVillage          9366          NaN
# ...                ...           ...           ...          ...
# 1255031              2     Complex+D          1092          NaN
# 1255032              0    SonarÀgora           583          NaN
# 1255038              0    SonarÀgora           583          NaN
# 1255041              1  Project Area          2603          NaN
# 1255043              1  Project Area          2603          NaN
#
# [161479 rows x 23 columns]

# %% [markdown]
# Assigning an explicit label for the event title and concatenating the two dataframes into the final `trajectories_events_day`.

# %%
unmatched_points_events_day['event_title'] = 'No event'

# %%
trajectories_events_day = pd.concat([trajectories_events_matched_day, unmatched_points_events_day]).sort_values(by=['uid','datetime'])
trajectories_events_day.drop(columns='geometry')
# Out:
#                                                        uid  \
# 0        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 1        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 2        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 3        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 4        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# ...                                                    ...
# 1191048  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255041  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1191050  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255043  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1191052  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
#
#          macaddr_randomized  tid  floor_num_added label_day_floor_change_id  \
# 0                         1    2                0                       2_0
# 1                         1    2                0                       2_0
# 2                         1    2                0                       2_0
# 3                         1    2                0                       2_0
# 4                         1    2                0                       2_0
# ...                     ...  ...              ...                       ...
# 1191048                   0    2                0                       2_0
# 1255041                   0    2                1                       2_1
# 1191050                   0    2                0                       2_2
# 1255043                   0    2                1                       2_3
# 1191052                   0    2                0                       2_4
#
#                          datetime  timestamp_ap        lat       lng  \
# 0       2024-06-14 17:45:49+02:00    1718379949  41.373153  2.151547
# 1       2024-06-14 17:56:08+02:00    1718380568  41.373399  2.151526
# 2       2024-06-14 17:57:26+02:00    1718380646  41.373175  2.151470
# 3       2024-06-14 17:57:57+02:00    1718380677  41.373399  2.151526
# 4       2024-06-14 17:59:15+02:00    1718380755  41.373175  2.151470
# ...                           ...           ...        ...       ...
# 1191048 2024-06-14 20:26:30+02:00    1718389590  41.372121  2.151921
# 1255041 2024-06-14 23:06:18+02:00    1718399178  41.372263  2.152061
# 1191050 2024-06-14 23:07:24+02:00    1718399244  41.372204  2.151938
# 1255043 2024-06-14 23:08:08+02:00    1718399288  41.372263  2.152061
# 1191052 2024-06-14 23:09:13+02:00    1718399353  41.372204  2.151938
#
#          vendor_name  ... activity_type         stage  music_type  genre  \
# 0                NaN  ...         Music  SonarVillage          DJ    NaN
# 1                NaN  ...         Music  SonarVillage          DJ    NaN
# 2                NaN  ...         Music  SonarVillage          DJ    NaN
# 3                NaN  ...         Music  SonarVillage          DJ    NaN
# 4                NaN  ...         Music  SonarVillage          DJ    NaN
# ...              ...  ...           ...           ...         ...    ...
# 1191048  Apple, Inc.  ...           NaN   NA-lounge+d         NaN    NaN
# 1255041  Apple, Inc.  ...           NaN  Project Area         NaN    NaN
# 1191050  Apple, Inc.  ...           NaN   NA-lounge+d         NaN    NaN
# 1255043  Apple, Inc.  ...           NaN  Project Area         NaN    NaN
# 1191052  Apple, Inc.  ...           NaN   NA-lounge+d         NaN    NaN
#
#          genre_grouped  views_youtube                  polygon_name  \
# 0                  NaN            NaN  SONAR DIA - SonarVillage VIP
# 1                  NaN            NaN  SONAR DIA - SonarVillage VIP
# 2                  NaN            NaN  SONAR DIA - SonarVillage VIP
# 3                  NaN            NaN  SONAR DIA - SonarVillage VIP
# 4                  NaN            NaN  SONAR DIA - SonarVillage VIP
# ...                ...            ...                           ...
# 1191048            NaN            NaN          SONAR DIA - Lounge+D
# 1255041            NaN            NaN      SONAR DIA - Project Area
# 1191050            NaN            NaN          SONAR DIA - Lounge+D
# 1255043            NaN            NaN      SONAR DIA - Project Area
# 1191052            NaN            NaN          SONAR DIA - Lounge+D
#
#         source_gis_file stage_area_m2 polygon_floor
# 0                    p3        9366.0             0
# 1                    p3        9366.0             0
# 2                    p3        9366.0             0
# 3                    p3        9366.0             0
# 4                    p3        9366.0             0
# ...                 ...           ...           ...
# 1191048            p5.0         608.0             0
# 1255041            p5.1        2603.0             1
# 1191050            p5.0         608.0             0
# 1255043            p5.1        2603.0             1
# 1191052            p5.0         608.0             0
#
# [1191045 rows x 32 columns]

# %% [markdown]
# **The points were correctly associated with their corresponding events.** The difference in size between this table and the original trajectories is just the points that do not fall within the polygons anymore due to the trajectory compression.
#
# Also, there is a small difference between the size of the geographically unmatched points in the end of the process and the points not matched above (`no_points_in_polygon`) because the latter did not take into accound the floor number and needed the association with the trajectories' floor number (manually checked).

# %%
no_points_in_polygon_updated =  get_unmatched_points(trajectories_day, 
                                                     trajectories_events_day,
                                                     columns_join=['uid','datetime'])

no_points_in_polygon_updated.drop(columns={'geometry_x','geometry_y'})
# Out:
#                                                        uid  \
# 412132   544216fa2250cf4925003407403cba9c1d0c46019a29ba...
# 412137   544216fa2250cf4925003407403cba9c1d0c46019a29ba...
# 470447   61b1ce6e61415207dcc8fe54e9577c4ed6e067d823ba08...
# 560204   770fa04ab23e364f9de417304185dcdbe291ac94c5a338...
# 796784   a359cd7daae5899256efe4c5d1342a86dfd2d85fa15a06...
# 925297   c1f1d408cdda39d3a7d46b0395afae9f8fd48649cae223...
# 925300   c1f1d408cdda39d3a7d46b0395afae9f8fd48649cae223...
# 1129356  f2a02bc67a50072c12d3fd6d7d58307426681dd95ff02e...
#
#          macaddr_randomized_x  tid_x  floor_num_added_x  \
# 412132                      1      3                  0
# 412137                      1      3                  0
# 470447                      1      3                  0
# 560204                      1      1                  0
# 796784                      1      2                  0
# 925297                      1      2                  0
# 925300                      1      2                  0
# 1129356                     1      2                  0
#
#         label_day_floor_change_id_x                  datetime  timestamp_ap_x  \
# 412132                          3_4 2024-06-15 17:20:53+02:00      1718464853
# 412137                          3_4 2024-06-15 17:22:43+02:00      1718464963
# 470447                          3_0 2024-06-15 20:12:33+02:00      1718475153
# 560204                          1_9 2024-06-13 14:53:06+02:00      1718283186
# 796784                          2_4 2024-06-14 20:54:13+02:00      1718391253
# 925297                          2_0 2024-06-14 23:03:57+02:00      1718399037
# 925300                          2_0 2024-06-14 23:05:46+02:00      1718399146
# 1129356                         2_0 2024-06-14 20:35:21+02:00      1718390121
#
#              lat_x     lng_x vendor_name_x  ... activity_type stage  \
# 412132   41.372194  2.151736           NaN  ...           NaN   NaN
# 412137   41.372194  2.151736           NaN  ...           NaN   NaN
# 470447   41.372230  2.151837           NaN  ...           NaN   NaN
# 560204   41.372223  2.151820           NaN  ...           NaN   NaN
# 796784   41.372219  2.151811           NaN  ...           NaN   NaN
# 925297   41.373066  2.151757           NaN  ...           NaN   NaN
# 925300   41.373066  2.151757           NaN  ...           NaN   NaN
# 1129356  41.372218  2.151805           NaN  ...           NaN   NaN
#
#          music_type  genre  genre_grouped  views_youtube  polygon_name  \
# 412132          NaN    NaN            NaN            NaN           NaN
# 412137          NaN    NaN            NaN            NaN           NaN
# 470447          NaN    NaN            NaN            NaN           NaN
# 560204          NaN    NaN            NaN            NaN           NaN
# 796784          NaN    NaN            NaN            NaN           NaN
# 925297          NaN    NaN            NaN            NaN           NaN
# 925300          NaN    NaN            NaN            NaN           NaN
# 1129356         NaN    NaN            NaN            NaN           NaN
#
#          source_gis_file  stage_area_m2 polygon_floor
# 412132               NaN            NaN          <NA>
# 412137               NaN            NaN          <NA>
# 470447               NaN            NaN          <NA>
# 560204               NaN            NaN          <NA>
# 796784               NaN            NaN          <NA>
# 925297               NaN            NaN          <NA>
# 925300               NaN            NaN          <NA>
# 1129356              NaN            NaN          <NA>
#
# [8 rows x 46 columns]

# %% [markdown]
# ### Associating each updated trajectory point to their corresponding H3 cells

# %% [markdown]
# For plotting purposes, I also get the updated h3 cell from the h3 API. As the trajectory compression might have sligthly changed some locations, I recoompute the h3_cell for safety.

# %%
trajectories_events_day['h3_cell'] = [h3.latlng_to_cell(lat, lng, 13) for lat, lng in zip(trajectories_events_day['lat'], trajectories_events_day['lng'])]

# %%
print(f"There are {(trajectories_events_day['h3_cell_original'] != trajectories_events_day['h3_cell']).sum()} points that changed their h3_cell after the trajectory preprocessing.")
# Out:
# There are 6120 points that changed their h3_cell after the trajectory preprocessing.

# %% [markdown]
# ## Writing the trajectories with their associated events

# %% [markdown]
# ### Writing the Sónar by night files.

# %% [markdown]
# Selecting the final columns that will be analyzed.

# %%
trajectories_events_night.columns
# Out:
# Index(['uid', 'macaddr_randomized', 'tid', 'datetime', 'timestamp_ap', 'lat',
#        'lng', 'vendor_name', 'h3_cell_original', 'stage_original',
#        'observations_user_night_original', 'timespan_minutes_night_original',
#        'num_distinct_stage_night_original', 'minutes_per_stage_original',
#        'geometry', 'index_right', 'sonar_type', 'day_label', 'start_datetime',
#        'end_datetime', 'event_title', 'activity_type', 'stage', 'music_type',
#        'genre', 'genre_grouped', 'views_youtube', 'polygon_name',
#        'source_gis_file', 'stage_area_m2', 'h3_cell'],
#       dtype='object')

# %%
selected_columns_night = ['uid', 'macaddr_randomized',
                          'tid',                               # Corresponds to the renamed label_night 
                          'datetime', 'timestamp_ap',          # Both formats if I need to do quick computations with the trajectories' timestamps
                          'lat', 'lng', 
                          'vendor_name', 
                          'sonar_type',                        # 'day_label', I discard the day_label column from the timetables to avoid confusions 
                          'start_datetime', 'end_datetime',    # Start and end of the events 
                          'event_title','music_type',          # activity_type is always Music in Sónar by night
                          'genre_grouped','views_youtube', 
                          'polygon_name', 'stage', 'stage_area_m2', 'h3_cell', # Relative location columns
                          'timespan_minutes_night_original', 'num_distinct_stage_night_original', 'minutes_per_stage_original',   # Old metrics obtained before trajectory preprocessing
                          'geometry'
                          ]
trajectories_events_night = trajectories_events_night[selected_columns_night]
trajectories_events_night.drop(columns='geometry')
# Out:
#                                                       uid  macaddr_randomized  \
# 0       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 1       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 2       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 3       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# 4       00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...                   1
# ...                                                   ...                 ...
# 630777  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630778  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630779  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630780  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
# 630781  fff1c4c048bd5253bb7c3996ed466e303c6b8253a93dbe...                   1
#
#         tid                  datetime  timestamp_ap        lat       lng  \
# 0         2 2024-06-15 22:38:47+02:00    1718483927  41.353501  2.129162
# 1         2 2024-06-15 22:39:19+02:00    1718483959  41.353440  2.129005
# 2         2 2024-06-15 22:40:37+02:00    1718484037  41.353501  2.129162
# 3         2 2024-06-15 22:49:15+02:00    1718484555  41.353426  2.128963
# 4         2 2024-06-15 22:49:21+02:00    1718484561  41.353365  2.128970
# ...     ...                       ...           ...        ...       ...
# 630777    1 2024-06-15 06:26:21+02:00    1718425581  41.354558  2.130617
# 630778    1 2024-06-15 06:26:35+02:00    1718425595  41.354326  2.130864
# 630779    1 2024-06-15 06:27:57+02:00    1718425677  41.354300  2.130898
# 630780    1 2024-06-15 06:28:41+02:00    1718425721  41.354254  2.130618
# 630781    1 2024-06-15 06:31:37+02:00    1718425897  41.353698  2.132315
#
#        vendor_name      sonar_type            start_datetime  ... music_type  \
# 0              NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
# 1              NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
# 2              NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
# 3              NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
# 4              NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
# ...            ...             ...                       ...  ...        ...
# 630777         NaN  Sónar by Night 2024-06-15 05:30:00+02:00  ...         DJ
# 630778         NaN  Sónar by Night 2024-06-15 05:30:00+02:00  ...         DJ
# 630779         NaN  Sónar by Night 2024-06-15 05:30:00+02:00  ...         DJ
# 630780         NaN  Sónar by Night 2024-06-15 05:30:00+02:00  ...         DJ
# 630781         NaN  Sónar by Night 2024-06-14 19:50:00+02:00  ...        NaN
#
#               genre_grouped views_youtube                  polygon_name  \
# 0                       NaN           NaN           SONAR NIT - Entrada
# 1                       NaN           NaN           SONAR NIT - Entrada
# 2                       NaN           NaN           SONAR NIT - Entrada
# 3                       NaN           NaN           SONAR NIT - Entrada
# 4                       NaN           NaN           SONAR NIT - Entrada
# ...                     ...           ...                           ...
# 630777  electronic_hypnotic           0.0          SONAR NIT - SonarLab
# 630778  electronic_hypnotic           0.0          SONAR NIT - SonarLab
# 630779  electronic_hypnotic           0.0  SONAR NIT - SonarLab Barra 1
# 630780  electronic_hypnotic           0.0          SONAR NIT - SonarLab
# 630781                  NaN           NaN      SONAR NIT - Restauración
#
#                         stage stage_area_m2          h3_cell  \
# 0                  NA-Entrada          5438  8d394461e82b5bf
# 1                  NA-Entrada          5438  8d394461e82a67f
# 2                  NA-Entrada          5438  8d394461e82b5bf
# 3                  NA-Entrada          5438  8d394461e82a67f
# 4                  NA-Entrada          5438  8d394461e82a6ff
# ...                       ...           ...              ...
# 630777  SonarLab x Printworks          9171  8d394461e95b2ff
# 630778  SonarLab x Printworks          9171  8d394461e875abf
# 630779  SonarLab x Printworks          9171  8d394461e87533f
# 630780  SonarLab x Printworks          9171  8d394461e875cff
# 630781        NA-Restauración          5695  8d394461e84027f
#
#         timespan_minutes_night_original num_distinct_stage_night_original  \
# 0                                340.90                                 7
# 1                                340.90                                 7
# 2                                340.90                                 7
# 3                                340.90                                 7
# 4                                340.90                                 7
# ...                                 ...                               ...
# 630777                           510.43                                 5
# 630778                           510.43                                 5
# 630779                           510.43                                 5
# 630780                           510.43                                 5
# 630781                           510.43                                 5
#
#         minutes_per_stage_original
# 0                            48.70
# 1                            48.70
# 2                            48.70
# 3                            48.70
# 4                            48.70
# ...                            ...
# 630777                      102.09
# 630778                      102.09
# 630779                      102.09
# 630780                      102.09
# 630781                      102.09
#
# [630781 rows x 22 columns]

# %% [markdown]
# Writing the files.

# %%
trajectories_events_night.to_csv(os.path.join(path_trajectories_events,'trajectories_events_night_compressed.csv'),index=False)

# %% [markdown]
# ### Writing the Sónar by day files.

# %% [markdown]
# Selecting the final columns that will be analyzed.

# %%
trajectories_events_day.columns
# Out:
# Index(['uid', 'macaddr_randomized', 'tid', 'floor_num_added',
#        'label_day_floor_change_id', 'datetime', 'timestamp_ap', 'lat', 'lng',
#        'vendor_name', 'h3_cell_original', 'stage_original',
#        'observations_user_day_original', 'timespan_minutes_day_original',
#        'num_distinct_stage_day_original', 'minutes_per_stage_original',
#        'geometry', 'index_right', 'sonar_type', 'day_label', 'start_datetime',
#        'end_datetime', 'event_title', 'activity_type', 'stage', 'music_type',
#        'genre', 'genre_grouped', 'views_youtube', 'polygon_name',
#        'source_gis_file', 'stage_area_m2', 'polygon_floor', 'h3_cell'],
#       dtype='object')

# %%
selected_columns_day = ['uid', 'macaddr_randomized',
                        'tid',                                                              # Corresponds to the renamed label_night
                        'floor_num_added', 'label_day_floor_change_id',                     # Columns related to the movement between floor
                        'datetime', 'timestamp_ap',                                         # Both formats if I need to do quick computations with the trajectories' timestamps
                        'lat', 'lng', 
                        'vendor_name', 
                        'sonar_type',                                                       # 'day_label', I discard the day_label column from the timetables to avoid confusions 
                        'start_datetime', 'end_datetime',                                   # Start and end of the events 
                        'event_title', 'activity_type', 'music_type', 
                        'genre_grouped','views_youtube',                            
                        'polygon_name', 'stage', 'h3_cell', 'stage_area_m2',                # Location related columns
                        'timespan_minutes_day_original', 'num_distinct_stage_day_original', 'minutes_per_stage_original',   # Old metrics obtained before trajectory preprocessing
                        'geometry'
                        ]
trajectories_events_day = trajectories_events_day[selected_columns_day]
trajectories_events_day.drop(columns='geometry')
# Out:
#                                                        uid  \
# 0        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 1        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 2        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 3        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# 4        00154bc5831501b8bd95273b1181d9330c3bf5f34b1961...
# ...                                                    ...
# 1191048  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255041  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1191050  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1255043  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
# 1191052  ffea2cb3179e7305ccb7b75a3f11c5a226710387fd72c5...
#
#          macaddr_randomized  tid  floor_num_added label_day_floor_change_id  \
# 0                         1    2                0                       2_0
# 1                         1    2                0                       2_0
# 2                         1    2                0                       2_0
# 3                         1    2                0                       2_0
# 4                         1    2                0                       2_0
# ...                     ...  ...              ...                       ...
# 1191048                   0    2                0                       2_0
# 1255041                   0    2                1                       2_1
# 1191050                   0    2                0                       2_2
# 1255043                   0    2                1                       2_3
# 1191052                   0    2                0                       2_4
#
#                          datetime  timestamp_ap        lat       lng  \
# 0       2024-06-14 17:45:49+02:00    1718379949  41.373153  2.151547
# 1       2024-06-14 17:56:08+02:00    1718380568  41.373399  2.151526
# 2       2024-06-14 17:57:26+02:00    1718380646  41.373175  2.151470
# 3       2024-06-14 17:57:57+02:00    1718380677  41.373399  2.151526
# 4       2024-06-14 17:59:15+02:00    1718380755  41.373175  2.151470
# ...                           ...           ...        ...       ...
# 1191048 2024-06-14 20:26:30+02:00    1718389590  41.372121  2.151921
# 1255041 2024-06-14 23:06:18+02:00    1718399178  41.372263  2.152061
# 1191050 2024-06-14 23:07:24+02:00    1718399244  41.372204  2.151938
# 1255043 2024-06-14 23:08:08+02:00    1718399288  41.372263  2.152061
# 1191052 2024-06-14 23:09:13+02:00    1718399353  41.372204  2.151938
#
#          vendor_name  ... music_type genre_grouped views_youtube  \
# 0                NaN  ...         DJ           NaN           NaN
# 1                NaN  ...         DJ           NaN           NaN
# 2                NaN  ...         DJ           NaN           NaN
# 3                NaN  ...         DJ           NaN           NaN
# 4                NaN  ...         DJ           NaN           NaN
# ...              ...  ...        ...           ...           ...
# 1191048  Apple, Inc.  ...        NaN           NaN           NaN
# 1255041  Apple, Inc.  ...        NaN           NaN           NaN
# 1191050  Apple, Inc.  ...        NaN           NaN           NaN
# 1255043  Apple, Inc.  ...        NaN           NaN           NaN
# 1191052  Apple, Inc.  ...        NaN           NaN           NaN
#
#                          polygon_name         stage          h3_cell  \
# 0        SONAR DIA - SonarVillage VIP  SonarVillage  8d394461ca7267f
# 1        SONAR DIA - SonarVillage VIP  SonarVillage  8d394461ca72bbf
# 2        SONAR DIA - SonarVillage VIP  SonarVillage  8d394461ca7273f
# 3        SONAR DIA - SonarVillage VIP  SonarVillage  8d394461ca72bbf
# 4        SONAR DIA - SonarVillage VIP  SonarVillage  8d394461ca7273f
# ...                               ...           ...              ...
# 1191048          SONAR DIA - Lounge+D   NA-lounge+d  8d394461ca520bf
# 1255041      SONAR DIA - Project Area  Project Area  8d394461ca52abf
# 1191050          SONAR DIA - Lounge+D   NA-lounge+d  8d394461ca5203f
# 1255043      SONAR DIA - Project Area  Project Area  8d394461ca52abf
# 1191052          SONAR DIA - Lounge+D   NA-lounge+d  8d394461ca5203f
#
#         stage_area_m2  timespan_minutes_day_original  \
# 0              9366.0                         256.27
# 1              9366.0                         256.27
# 2              9366.0                         256.27
# 3              9366.0                         256.27
# 4              9366.0                         256.27
# ...               ...                            ...
# 1191048         608.0                         736.40
# 1255041        2603.0                         736.40
# 1191050         608.0                         736.40
# 1255043        2603.0                         736.40
# 1191052         608.0                         736.40
#
#         num_distinct_stage_day_original minutes_per_stage_original
# 0                                     4                      64.07
# 1                                     4                      64.07
# 2                                     4                      64.07
# 3                                     4                      64.07
# 4                                     4                      64.07
# ...                                 ...                        ...
# 1191048                               4                     184.10
# 1255041                               4                     184.10
# 1191050                               4                     184.10
# 1255043                               4                     184.10
# 1191052                               4                     184.10
#
# [1191045 rows x 25 columns]

# %% [markdown]
# Writing the files.

# %%
trajectories_events_day.to_csv(os.path.join(path_trajectories_events,'trajectories_events_day_compressed.csv'),index=False)
